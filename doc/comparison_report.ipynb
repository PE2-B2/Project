# %% [markdown]
# # Comparison report
# ## Visualize analyzed data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df_train = pd.read_csv('../res/csvRes/analyzedResult.csv')

# %%
sns.swarmplot(x = 'Wafer', y = 'ErrorFlag', data = df_train)
sns.set_style("darkgrid")
plt.title('ErrorFlag for rsq of I-V', fontsize = 18)
plt.xlabel('WaferID', fontsize = 13)
plt.ylabel('ErrorFlag', fontsize = 13)
# Out:
# Text(0, 0.5, 'ErrorFlag')

# %%
sns.swarmplot(x = 'Wafer', y = 'Analysis Wavelength', data = df_train)
sns.set_style("darkgrid")
plt.title('Analysis Wavelength', fontsize = 18)
plt.xlabel('WaferID', fontsize = 13)
plt.ylabel('Wavelength [nm]', fontsize = 13)
# Out:
# Text(0, 0.5, 'Wavelength [nm]')

# %%
fig = plt.figure(figsize = (15, 5))
plt.title('Rsq of Ref.spectrum comparison', fontsize=20)
sns.set_style("darkgrid")

pic_1 = fig.add_subplot(1, 2, 1)
sns.swarmplot(x = 'Wafer', y = 'Rsq of Ref. spectrum', data = df_train, ax = pic_1)
plt.xlabel('Wafer ID', fontsize=13)
plt.ylabel('Rsq of ref. spec.', fontsize=13)

pic_2 = fig.add_subplot(1, 2, 2)
sns.boxplot(x = 'Wafer', y = 'Rsq of Ref. spectrum', data = df_train, ax = area02)
plt.xlabel('Wafer ID', fontsize=13)
plt.ylabel('Rsq of ref. spec.', fontsize=13)
# Out:
# Text(0, 0.5, 'Rsq of ref. spec.')

# %%
fig = plt.figure(figsize = (15, 5))
plt.title('Max transmission of Ref spec(dB) comparison', fontsize = 20)
sns.set_style("darkgrid")

pic_1 = fig.add_subplot(1, 2, 1)
sns.swarmplot(x = 'Wafer', y = 'Max transmission of Ref. spec. (dB)', data = df_train, ax = pic_1)
plt.xlabel('Wafer ID', fontsize = 13)
plt.ylabel('Max transmission of ref. spec.', fontsize = 13)
# plt.xticks([1, 2, 3, 4], ['D07', 'D08', 'D23', 'D24'])

pic_2 = fig.add_subplot(1, 2, 2)
sns.boxplot(x = 'Wafer', y = 'Max transmission of Ref. spec. (dB)', data = df_train, ax = pic_2)
plt.xlabel('Wafer ID', fontsize = 13)
plt.ylabel('Max transmission of ref. spec.', fontsize = 13)
# plt.xticks([1, 2, 3, 4], ['D07', 'D08', 'D23', 'D24'])
# Out:
# ([<matplotlib.axis.XTick at 0x2262043b100>,
# ...
#  [Text(1, 0, 'D07'), Text(2, 0, 'D08'), Text(3, 0, 'D23'), Text(4, 0, 'D24')])

# %%
fig = plt.figure(figsize = (15, 5))
plt.title('Rsq of I-V comparison', fontsize = 20)
sns.set_style("darkgrid")

pic_1 = fig.add_subplot(1, 2, 1)
sns.swarmplot(x = 'Wafer', y = 'Rsq of IV', data = df_train, ax = pic_1)
plt.xlabel('Wafer ID', fontsize = 13)
plt.ylabel('Rsq of IV', fontsize = 13)

pic_2 = fig.add_subplot(1, 2, 2)
sns.boxplot(x = 'Wafer', y = 'Rsq of IV', data = df_train, ax = pic_2)
plt.xlabel('Wafer ID', fontsize = 13)
plt.ylabel('Rsq of IV', fontsize = 13)
# Out:
# Text(0, 0.5, 'Rsq of IV')

# %%
fig = plt.figure(figsize = (15, 5))
plt.title('I at -2V comparison', fontsize = 20)
sns.set_style("darkgrid")

pic_1 = fig.add_subplot(1, 2, 1)
sns.swarmplot(x = 'Wafer', y = 'I at -2V', data = df_train, ax = pic_1)
plt.xlabel('Wafer ID', fontsize = 13)
plt.ylabel('I at -2V', fontsize = 13)

pic_2 = fig.add_subplot(1, 2, 2)
sns.boxplot(x = 'Wafer', y = 'I at -2V', data = df_train, ax = pic_2)
plt.xlabel('Wafer ID', fontsize = 13)
plt.ylabel('I at -2V', fontsize = 13)
# Out:
# Text(0, 0.5, 'I at -2V')

# %%
fig = plt.figure(figsize = (15, 5))
plt.title('I at -1V comparison', fontsize = 20)
sns.set_style("darkgrid")

pic_1 = fig.add_subplot(1, 2, 1)
sns.swarmplot(x = 'Wafer', y = 'I at -1V', data = df_train, ax = pic_1)
plt.xlabel('Wafer ID', fontsize = 13)
plt.ylabel('I at -1V', fontsize = 13)

pic_2 = fig.add_subplot(1, 2, 2)
sns.boxplot(x = 'Wafer', y = 'I at -1V', data = df_train, ax = pic_2)
plt.xlabel('Wafer ID', fontsize = 13)
plt.ylabel('I at -1V', fontsize = 13)
# Out:
# Text(0, 0.5, 'I at -1V')

# %%
fig = plt.figure(figsize = (15, 5))
plt.title('I at 1V comparison', fontsize = 20)
sns.set_style("darkgrid")

pic_1 = fig.add_subplot(1, 2, 1)
sns.swarmplot(x = 'Wafer', y = 'I at 1V', data = df_train, ax = pic_1)
plt.xlabel('Wafer ID', fontsize = 13)
plt.ylabel('I at 1V', fontsize = 13)

pic_2 = fig.add_subplot(1, 2, 2)
sns.boxplot(x = 'Wafer', y = 'I at 1V', data = df_train, ax = pic_2)
plt.xlabel('Wafer ID', fontsize = 13)
plt.ylabel('I at 1V', fontsize = 13)
# Out:
# Text(0, 0.5, 'I at 1V')
